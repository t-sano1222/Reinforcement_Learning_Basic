# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# red wall
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# state
plt.text(0.5, 2.3, 'START', size=14, ha='center')
plt.text(0.5, 2.5, 's0', size=14, ha='center')
plt.text(1.5, 2.5, 's1', size=14, ha='center')
plt.text(2.5, 2.5, 's2', size=14, ha='center')
plt.text(0.5, 1.5, 's3', size=14, ha='center')
plt.text(1.5, 1.5, 's4', size=14, ha='center')
plt.text(2.5, 1.5, 's5', size=14, ha='center')
plt.text(0.5, 0.5, 's6', size=14, ha='center')
plt.text(1.5, 0.5, 's7', size=14, ha='center')
plt.text(2.5, 0.5, 's8', size=14, ha='center')
plt.text(2.5, 0.3, 'GOAL', size=14, ha='center')

ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom='off', top='off', labelbottom='off', right='off', left='off', labelleft='off')

# agent
line, = ax.plot([0.5], [2.5], marker='o', color='g', markersize=60)

# %% [markdown]
# 初期方策のパラメータ：行は状態，列は移動方向↑，→，↓，←

# %%
# parameters of an initial policy : theta_0

theta_0 = np.array([[np.nan, 1, 1, np.nan], #s0
                    [np.nan, 1, np.nan, 1], #s1
                    [np.nan, np.nan, 1, 1], #s2
                    [1, 1, 1, np.nan], #s3
                    [np.nan, np.nan, 1, 1], # s4
                    [1, np.nan, np.nan, np.nan], #s5
                    [1, np.nan, np.nan, np.nan], #s6
                    [1, 1, np.nan, np.nan], #s7 #s8 is a goal
                   ])

# %%
[a, b] = theta_0.shape
Q = np.random.rand(a,b) * theta_0

# %%
# convert theta to policy pi

def simple_convert_into_pi_from_theta(theta):
    # simple ratio
    [m, n] = theta.shape
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])
    
    pi = np.nan_to_num(pi)
    
    return pi

pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# epsilon-greedy

def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    
    # select action
    if np.random.rand() < epsilon:
        # random exploration
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        next_direction = direction[np.nanargmax(Q[s, :])]
        
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3
        
    return action

def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]
     
    if next_direction == 'up':
        s_next = s - 3
    elif next_direction == 'right':
        s_next = s + 1
    elif next_direction == 'down':
        s_next = s + 3
    elif next_direction == 'left':
        s_next = s - 1
        
    return s_next

# %%
def Sarsa(s, a, r, s_next, a_next, Q, eta,gamma):
    if s_next == 8:
        Q[s, a] = Q[s, a] + eta * (r -Q[s, a])
        
    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * Q[s_next, a_next] -Q[s, a])
        
    return Q

# %%
def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0
    a = a_next = get_action(s, Q, epsilon, pi)
    s_a_history = [[0, np.nan]]
    
    while (1):
        a = a_next
        
        s_a_history[-1][1] = a
        s_next = get_s_next(s, a, Q, epsilon, pi)
        
        s_a_history.append([s_next, np.nan])
        
        if s_next == 8:
            r = 1
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            
        Q = Sarsa(s, a, r, s_next, a_next, Q, eta, gamma)
        
        if s_next == 8:
            break
        else:
            s = s_next
            
    return [s_a_history, Q]

# %%
eta = 0.1
gamma = 0.9
epsilon = 0.5
v = np.nanargmax(Q, axis=1)
is_continue = True
episode = 1

while is_continue:
    print("episode:" + str(episode))
    
    epsilon = epsilon / 2
    
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)
    
    new_v = np.nanmax(Q, axis=1)
    print(np.sum(np.abs(new_v - v))) # state-value
    v = new_v
    
    print("Elapsed steps were " + str(len(s_a_history) - 1) + "steps")
    
    episode = episode + 1
    if  episode > 100:
        break
# Out:
# episode:1
# 6.877627102744998
# Elapsed steps were 522steps
# episode:2
# 0.4216839659230288
# Elapsed steps were 212steps
# episode:3
# 0.14640349220134752
# Elapsed steps were 50steps
# episode:4
# 0.09282223782533416
# Elapsed steps were 18steps
# episode:5
# 0.07942032104251573
# Elapsed steps were 12steps
# episode:6
# 0.07601857581784643
# Elapsed steps were 10steps
# episode:7
# 0.07471321375336987
# Elapsed steps were 10steps
# episode:8
# 0.06387837200574792
# Elapsed steps were 4steps
# episode:9
# 0.07297908287039051
# Elapsed steps were 10steps
# episode:10
# 0.06198632290636463
# Elapsed steps were 4steps
# episode:11
# 0.06879438166642593
# Elapsed steps were 10steps
# episode:12
# 0.05998403038396999
# Elapsed steps were 4steps
# episode:13
# 0.059328947768202744
# Elapsed steps were 4steps
# episode:14
# 0.05861572716786423
# Elapsed steps were 4steps
# episode:15
# 0.05784097599378751
# Elapsed steps were 4steps
# episode:16
# 0.05700276889897149
# Elapsed steps were 4steps
# episode:17
# 0.056100562497264195
# Elapsed steps were 4steps
# episode:18
# 0.05513507554419833
# Elapsed steps were 4steps
# episode:19
# 0.05410814798228708
# Elapsed steps were 4steps
# episode:20
# 0.0530225891588364
# Elapsed steps were 4steps
# episode:21
# 0.05188202301032352
# Elapsed steps were 4steps
# episode:22
# 0.05069073597702034
# Elapsed steps were 4steps
# episode:23
# 0.04945353178308887
# Elapsed steps were 4steps
# episode:24
# 0.04817559592179249
# Elapsed steps were 4steps
# episode:25
# 0.0468623716645587
# Elapsed steps were 4steps
# episode:26
# 0.04551944861746399
# Elapsed steps were 4steps
# episode:27
# 0.04415246423817765
# Elapsed steps were 4steps
# episode:28
# 0.04276701826612933
# Elapsed steps were 4steps
# episode:29
# 0.041368599679930396
# Elapsed steps were 4steps
# episode:30
# 0.03996252555496854
# Elapsed steps were 4steps
# episode:31
# 0.03855389103079032
# Elapsed steps were 4steps
# episode:32
# 0.03714752949596706
# Elapsed steps were 4steps
# episode:33
# 0.035747982044126714
# Elapsed steps were 4steps
# episode:34
# 0.03435947523762595
# Elapsed steps were 4steps
# episode:35
# 0.032985906225935946
# Elapsed steps were 4steps
# episode:36
# 0.031630834296876686
# Elapsed steps were 4steps
# episode:37
# 0.03029747798447341
# Elapsed steps were 4steps
# episode:38
# 0.028988716912706325
# Elapsed steps were 4steps
# episode:39
# 0.027707097616057275
# Elapsed steps were 4steps
# episode:40
# 0.02645484264259812
# Elapsed steps were 4steps
# episode:41
# 0.0252338623111526
# Elapsed steps were 4steps
# episode:42
# 0.02404576855911955
# Elapsed steps were 4steps
# episode:43
# 0.022891890380549174
# Elapsed steps were 4steps
# episode:44
# 0.021773290414168867
# Elapsed steps were 4steps
# episode:45
# 0.02069078229758381
# Elapsed steps were 4steps
# episode:46
# 0.019644948456484568
# Elapsed steps were 4steps
# episode:47
# 0.01863615804612484
# Elapsed steps were 4steps
# episode:48
# 0.017664584806552752
# Elapsed steps were 4steps
# episode:49
# 0.016730224633087487
# Elapsed steps were 4steps
# episode:50
# 0.01583291269946918
# Elapsed steps were 4steps
# episode:51
# 0.01497234000312897
# Elapsed steps were 4steps
# episode:52
# 0.014148069230347948
# Elapsed steps were 4steps
# episode:53
# 0.013359549863929399
# Elapsed steps were 4steps
# episode:54
# 0.012606132477657184
# Elapsed steps were 4steps
# episode:55
# 0.011887082180510489
# Elapsed steps were 4steps
# episode:56
# 0.011201591189610727
# Elapsed steps were 4steps
# episode:57
# 0.01054879052444202
# Elapsed steps were 4steps
# episode:58
# 0.00992776082626079
# Elapsed steps were 4steps
# episode:59
# 0.009337542316022573
# Elapsed steps were 4steps
# episode:60
# 0.008777143911823049
# Elapsed steps were 4steps
# episode:61
# 0.008245551532983675
# Elapsed steps were 4steps
# episode:62
# 0.007741735622692758
# Elapsed steps were 4steps
# episode:63
# 0.0072646579247274135
# Elapsed steps were 4steps
# episode:64
# 0.006813277552365049
# Elapsed steps were 4steps
# episode:65
# 0.006386556389320064
# Elapsed steps were 4steps
# episode:66
# 0.005983463863515004
# Elapsed steps were 4steps
# episode:67
# 0.005602981134841145
# Elapsed steps were 4steps
# episode:68
# 0.005244104737895605
# Elapsed steps were 4steps
# episode:69
# 0.004905849720073352
# Elapsed steps were 4steps
# episode:70
# 0.004587252314435908
# Elapsed steps were 4steps
# episode:71
# 0.004287372185547311
# Elapsed steps were 4steps
# episode:72
# 0.004005294285011729
# Elapsed steps were 4steps
# episode:73
# 0.003740130351837956
# Elapsed steps were 4steps
# episode:74
# 0.0034910200910138744
# Elapsed steps were 4steps
# episode:75
# 0.0032571320618743904
# Elapsed steps were 4steps
# episode:76
# 0.0030376643059832897
# Elapsed steps were 4steps
# episode:77
# 0.0028318447423859583
# Elapsed steps were 4steps
# episode:78
# 0.002638931356222396
# Elapsed steps were 4steps
# episode:79
# 0.0024582122048562027
# Elapsed steps were 4steps
# episode:80
# 0.0022890052638832037
# Elapsed steps were 4steps
# episode:81
# 0.002130658133643659
# Elapsed steps were 4steps
# episode:82
# 0.0019825476251879026
# Elapsed steps were 4steps
# episode:83
# 0.0018440792430456376
# Elapsed steps were 4steps
# episode:84
# 0.0017146865806217937
# Elapsed steps were 4steps
# episode:85
# 0.0015938306426016569
# Elapsed steps were 4steps
# episode:86
# 0.0014809991073788664
# Elapsed steps were 4steps
# episode:87
# 0.0013757055412508823
# Elapsed steps were 4steps
# episode:88
# 0.0012774885749222697
# Elapsed steps were 4steps
# episode:89
# 0.001185911051747146
# Elapsed steps were 4steps
# episode:90
# 0.0011005591561029648
# Elapsed steps were 4steps
# episode:91
# 0.0010210415293391284
# Elapsed steps were 4steps
# episode:92
# 0.0009469883798479684
# Elapsed steps were 4steps
# episode:93
# 0.000878050593009716
# Elapsed steps were 4steps
# episode:94
# 0.0008138988460074659
# Elapsed steps were 4steps
# episode:95
# 0.0007542227318372285
# Elapsed steps were 4steps
# episode:96
# 0.0006987298962154442
# Elapsed steps were 4steps
# episode:97
# 0.0006471451905308845
# Elapsed steps were 4steps
# episode:98
# 0.0005992098434761672
# Elapsed steps were 4steps
# episode:99
# 0.0005546806535395854
# Elapsed steps were 4steps
# episode:100
# 0.000513329204130053
# Elapsed steps were 4steps
